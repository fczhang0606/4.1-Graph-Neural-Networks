# %%
# 《深入浅出图神经网络》（刘忠雨）

# %%
# ! pip install scipy
# ! pip install scikit-learn

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
import torch.optim as optim

from collections import namedtuple
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import os.path as osp
import pickle
import scipy.sparse as sp
from sklearn.manifold import TSNE
import urllib

# %%
# 自制格式
Data = namedtuple('Data', ['x', 'y', 'adjacency', 'train_mask', 'val_mask', 'test_mask'])


def tensor_from_numpy(x, device) :
    return torch.from_numpy(x).to(device)


class CoraData(object) :

    # https://blog.csdn.net/zfhsfdhdfajhsr/article/details/116137598
    filenames = ["ind.cora.{}".format(name) 
                 for name in ['x', 'tx', 'allx', 'y', 'ty', 'ally', 'graph', 'test.index']]

    def __init__(self, data_root=
                 "/home/zhfc/github files/3.2-Graph-Neural-Networks/3-CS224W 2021 Winter: ML with Graphs/06-GCN/cora", 
                 rebuild=False) :

        """Cora数据，包括数据下载、处理、加载等功能
        当数据的缓存文件存在时，将使用缓存文件，否则将下载、进行处理，并缓存到磁盘

        处理之后的数据，可以通过属性 .data 获得，它将返回一个数据对象，包括如下几部分：（和原始下载不一致）
            * x: 全节点的特征，维度为 2708 * 1433 ，类型为 np.ndarray
            * y: 全节点的标签，维度为 2708 * 7 ，one-hot，类型为 np.ndarray
            * adjacency: 邻接矩阵，维度为 2708 * 2708 ，类型为 scipy.sparse.coo.coo_matrix
            * train_mask: 训练集掩码向量，维度为 2708*1 ，当节点属于训练集时，相应位置为True，否则False
            * val_mask: 验证集掩码向量，维度为 2708*1   ，当节点属于验证集时，相应位置为True，否则False
            * test_mask: 测试集掩码向量，维度为 2708*1  ，当节点属于测试集时，相应位置为True，否则False

        Args:
        ------
            data_root: string, optional
                存放数据的目录，原始数据路径: ..
                缓存数据路径: {data_root}/ch5_cached.pkl
            rebuild: boolean, optional
                是否需要重新构建数据集，当设为True时，如果存在缓存数据也会重建数据
        """

        self.data_root = data_root
        save_file = osp.join(self.data_root, "ch5_cached.pkl")
        if osp.exists(save_file) and not rebuild :
            print("using cached file: {}".format(save_file))
            self._data = pickle.load(open(save_file, "rb"))
        else :
            self._data = self.process_data()
            with open(save_file, "wb") as f :
                pickle.dump(self.data, f)  # 为什么不直接self._data?
            print("cached file: {}".format(save_file))

    @property  # 装饰器
    def data(self) :
        """返回Data数据对象，包括x、y、adjacency、train_mask、val_mask、test_mask"""
        return self._data

    def process_data(self) :

        """
        处理数据，得到节点特征、标签、邻接矩阵、训练集、验证集以及测试集
        引用自： https://github.com/rusty1s/pytorch_geometric
        """

        print("Process data ...")

        _, tx, allx, y, ty, ally, graph, test_index = [self.read_data(
            osp.join(self.data_root, name)) for name in self.filenames]

        train_index = np.arange(y.shape[0])  # 此处的y不是缓存data当中的全y，只有140个标签
        val_index = np.arange(y.shape[0], y.shape[0] + 500)  # 140～640
        sorted_test_index = sorted(test_index)  # 读取的值

        x = np.concatenate((allx, tx), axis=0)  # 构建全集
        y = np.concatenate((ally, ty), axis=0).argmax(axis=1)

        x[test_index] = x[sorted_test_index]
        y[test_index] = y[sorted_test_index]
        num_nodes = x.shape[0]  # 2708

        train_mask = np.zeros(num_nodes, dtype=np.bool_)
        val_mask   = np.zeros(num_nodes, dtype=np.bool_)
        test_mask  = np.zeros(num_nodes, dtype=np.bool_)

        train_mask[train_index] = True
        val_mask[val_index]     = True
        test_mask[test_index]   = True

        adjacency = self.build_adjacency(graph)

        print("Node's feature shape: ", x.shape)  # 2708 x 1433
        print("Node's label shape: ", y.shape)  # 2708 x 7
        print("Adjacency's shape: ", adjacency.shape)  # 2708 x 2708
        print("Number of training nodes: ", train_mask.sum())  # 140
        print("Number of validation nodes: ", val_mask.sum())  # 500
        print("Number of test nodes: ", test_mask.sum())  # 1000

        return Data(x=x, y=y, adjacency=adjacency, 
                    train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)

    @staticmethod
    def build_adjacency(adj_dict) :
        """根据邻接表创建邻接阵"""

        edge_index = []
        num_nodes = len(adj_dict)  # 表长
        for src, dst in adj_dict.items() :  # 有向
            edge_index.extend([src, v] for v in dst)
            edge_index.extend([v, src] for v in dst)

        # 去除重复的边
        edge_index = list(k for k, _ in itertools.groupby(sorted(edge_index)))  # 重排
        edge_index = np.asarray(edge_index)  # 转换类型
        adjacency = sp.coo_matrix(
                    ( np.ones(len(edge_index)), (edge_index[:, 0], edge_index[:, 1]) ), 
                    shape=(num_nodes, num_nodes), dtype="float32")  # 1放在哪里
        return adjacency

    @staticmethod
    def read_data(path) :
        """使用不同的方式读取原始数据以进一步处理"""
        name = osp.basename(path)
        if name == "ind.cora.test.index" :
            out = np.genfromtxt(path, dtype="int64")
            return out
        else :
            out = pickle.load(open(path, "rb"), encoding="latin1")
            out = out.toarray() if hasattr(out, "toarray") else out
            return out

    @staticmethod
    def normalization(adjacency) :
        """计算 L = (D^-0.5) * (A+I) * (D^-0.5)"""
        adjacency += sp.eye(adjacency.shape[0])  # 增加identity
        degree = np.array(adjacency.sum(1))
        d_hat = sp.diags(np.power(degree, -0.5).flatten())
        return d_hat.dot(adjacency).dot(d_hat).tocoo()

# %%
class GraphConvolution(nn.Module) :

    def __init__(self, input_dim, output_dim, use_bias=True) :

        """图卷积：L*X*\theta

        Args:
        ------
            input_dim: int
                节点输入特征的维度
            output_dim: int
                节点输出特征的维度
            use_bias: bool, optional
                是否使用偏置
        """

        super(GraphConvolution, self).__init__()

        self.input_dim  = input_dim
        self.output_dim = output_dim
        self.use_bias   = use_bias
        self.weight     = nn.Parameter(torch.Tensor(input_dim, output_dim))  # 参数

        if self.use_bias :
            self.bias = nn.Parameter(torch.Tensor(output_dim))
        else :
            self.register_parameter('bias', None)

        self.reset_parameters()

    def reset_parameters(self) :
        init.kaiming_uniform_(self.weight)
        if self.use_bias :
            init.zeros_(self.bias)

    def forward(self, adjacency, input_feature) :

        """邻接矩阵是稀疏矩阵，因此在计算时使用稀疏矩阵乘法

        Args:
        ------
            adjacency: torch.sparse.FloatTensor  # ???
                邻接矩阵
            input_feature: torch.Tensor
                输入特征
        """

        support = torch.mm(input_feature.cpu(), self.weight.cpu())
        output = torch.sparse.mm(adjacency.cpu(), support.cpu())  # 矩阵结合律
        output = output.cuda()
        if self.use_bias :
            output += self.bias
        return output

    def __repr__(self) :
        return self.__class__.__name__ + '('    \
            + str(self.input_dim)      + ' -> ' \
            + str(self.output_dim)     + ')'

# %%
class Model(nn.Module) :

    """
    定义一个包含两层GraphConvolution的模型
    """

    def __init__(self, input_dim=1433) :
        super(Model, self).__init__()
        self.gcn1 = GraphConvolution(input_dim, 16)
        self.gcn2 = GraphConvolution(16, 7)

    def forward(self, adjacency, feature) :
        h = F.relu(self.gcn1(adjacency, feature))
        logits = self.gcn2(adjacency, h)
        return logits  # logistic units

# %%
# 超参数定义
LEARNING_RATE = 0.1
WEIGHT_DACAY = 5e-4
EPOCHS = 200
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(torch.cuda.is_available())
# Out:
# True

# %%
# 加载数据，并转换为torch.Tensor
dataset = CoraData().data

# feature - label
node_feature = dataset.x / dataset.x.sum(1, keepdims=True)  # 归一化数据，使得每一行和为1
tensor_x     = tensor_from_numpy(node_feature, DEVICE)
tensor_y     = tensor_from_numpy(dataset.y, DEVICE)

# mask
tensor_train_mask = tensor_from_numpy(dataset.train_mask, DEVICE)
tensor_val_mask   = tensor_from_numpy(dataset.val_mask, DEVICE)
tensor_test_mask  = tensor_from_numpy(dataset.test_mask, DEVICE)

# A
normalize_adjacency = CoraData.normalization(dataset.adjacency)  # 规范化邻接矩阵

# sparse A
num_nodes, input_dim = node_feature.shape  # 2708 x 1433
indices = torch.from_numpy(np.asarray([normalize_adjacency.row, 
                                       normalize_adjacency.col]).astype('int64')).long()
values = torch.from_numpy(normalize_adjacency.data.astype(np.float32))
tensor_adjacency = torch.sparse.FloatTensor(indices, values, 
                                            (num_nodes, num_nodes)).to(DEVICE)
# Out:
# using cached file: /home/zhfc/github files/3.2-Graph-Neural-Networks/3-CS224W 2021 Winter: ML with Graphs/06-GCN/cora/ch5_cached.pkl

# %%
# setup
model = Model(input_dim).to(DEVICE)

criterion = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(), 
                       lr=LEARNING_RATE, 
                       weight_decay=WEIGHT_DACAY)

# %%
# 训练主体
def train() :

    model.train()  # nn模式

    loss_history    = []
    val_acc_history = []

    train_y = tensor_y[tensor_train_mask]  # 训练集的label

    for epoch in range(EPOCHS) :

        optimizer.zero_grad()
        logits = model(tensor_adjacency, tensor_x)  # 前向传播
        train_mask_logits = logits[tensor_train_mask]  # 只选训练节点进行监督
        loss = criterion(train_mask_logits, train_y)  # loss
        loss.backward()  # 反向传播计算参数梯度
        optimizer.step()  # 使用优化方法进行梯度更新

        train_acc, _, _ = test(tensor_train_mask)  # 计算当前模型在训练集上的准确率
        val_acc, _, _   = test(tensor_val_mask)  # 计算当前模型在验证集上的准确率

        # 记录训练过程中，损失值和准确率的变化，用于画图
        loss_history.append(loss.item())
        val_acc_history.append(val_acc.item())
        print("Epoch {:03d}: Loss {:.4f}, TrainAcc {:.4}, ValAcc {:.4f}".
              format(epoch, loss.item(), train_acc.item(), val_acc.item()))

    return loss_history, val_acc_history

# %%
# 测试主体
def test(mask) :

    model.eval()  ## nn模式

    with torch.no_grad() :  # 当前计算不需要反向传播

        logits = model(tensor_adjacency, tensor_x)  # 当前参数
        test_mask_logits = logits[mask]
        predict_y = test_mask_logits.max(1)[1]  # 取值最大预测概率类别
        accuarcy = torch.eq(predict_y, tensor_y[mask]).float().mean()

    return accuarcy, test_mask_logits.cpu().numpy(), tensor_y[mask].cpu().numpy()

# %%
# 画图
def plot_loss_and_acc(loss_history, val_acc_history) :

    fig = plt.figure()

    ax1 = fig.add_subplot(111)  # 画布分为n*n，n号区
    ax1.plot(range(len(loss_history)), loss_history, 
             c=np.array([255, 71, 90]) / 255.)
    plt.ylabel('Loss')

    ax2 = fig.add_subplot(111, sharex=ax1, frameon=False)
    ax2.plot(range(len(val_acc_history)), val_acc_history, 
             c=np.array([79, 179, 255]) / 255.)
    ax2.yaxis.tick_right()
    ax2.yaxis.set_label_position("right")
    plt.ylabel('ValAcc')

    plt.xlabel('Epoch')
    plt.title('Training Loss & Validation Accuracy')
    plt.show()

# %%
loss, val_acc = train()
test_acc, test_logits, test_label = test(tensor_test_mask)
print("Test accuarcy: ", test_acc.item())
# Out:
# Epoch 000: Loss 1.9425, TrainAcc 0.3643, ValAcc 0.2400
# Epoch 001: Loss 1.8744, TrainAcc 0.4857, ValAcc 0.2480
# Epoch 002: Loss 1.7765, TrainAcc 0.8357, ValAcc 0.6060
# Epoch 003: Loss 1.6401, TrainAcc 0.9071, ValAcc 0.6600
# Epoch 004: Loss 1.4851, TrainAcc 0.8786, ValAcc 0.6440
# Epoch 005: Loss 1.3177, TrainAcc 0.9143, ValAcc 0.6540
# Epoch 006: Loss 1.1470, TrainAcc 0.9357, ValAcc 0.6860
# Epoch 007: Loss 0.9795, TrainAcc 0.95, ValAcc 0.7320
# Epoch 008: Loss 0.8195, TrainAcc 0.9714, ValAcc 0.7580
# Epoch 009: Loss 0.6806, TrainAcc 0.9857, ValAcc 0.7680
# Epoch 010: Loss 0.5643, TrainAcc 0.9857, ValAcc 0.7640
# Epoch 011: Loss 0.4699, TrainAcc 0.9857, ValAcc 0.7820
# Epoch 012: Loss 0.3939, TrainAcc 0.9857, ValAcc 0.7900
# Epoch 013: Loss 0.3357, TrainAcc 0.9857, ValAcc 0.7880
# Epoch 014: Loss 0.2911, TrainAcc 0.9857, ValAcc 0.7960
# Epoch 015: Loss 0.2583, TrainAcc 0.9857, ValAcc 0.8060
# Epoch 016: Loss 0.2339, TrainAcc 0.9929, ValAcc 0.8000
# Epoch 017: Loss 0.2176, TrainAcc 1.0, ValAcc 0.8000
# Epoch 018: Loss 0.2061, TrainAcc 1.0, ValAcc 0.7960
# Epoch 019: Loss 0.1990, TrainAcc 1.0, ValAcc 0.7960
# Epoch 020: Loss 0.1947, TrainAcc 1.0, ValAcc 0.7880
# Epoch 021: Loss 0.1925, TrainAcc 1.0, ValAcc 0.7960
# Epoch 022: Loss 0.1906, TrainAcc 1.0, ValAcc 0.7920
# Epoch 023: Loss 0.1885, TrainAcc 1.0, ValAcc 0.7840
# Epoch 024: Loss 0.1859, TrainAcc 1.0, ValAcc 0.7920
# Epoch 025: Loss 0.1818, TrainAcc 0.9929, ValAcc 0.7880
# Epoch 026: Loss 0.1786, TrainAcc 1.0, ValAcc 0.7880
# Epoch 027: Loss 0.1756, TrainAcc 0.9929, ValAcc 0.7780
# Epoch 028: Loss 0.1677, TrainAcc 1.0, ValAcc 0.7920
# Epoch 029: Loss 0.1566, TrainAcc 1.0, ValAcc 0.7880
# Epoch 030: Loss 0.1513, TrainAcc 1.0, ValAcc 0.7800
# Epoch 031: Loss 0.1471, TrainAcc 1.0, ValAcc 0.7920
# Epoch 032: Loss 0.1394, TrainAcc 1.0, ValAcc 0.7920
# Epoch 033: Loss 0.1372, TrainAcc 1.0, ValAcc 0.7820
# Epoch 034: Loss 0.1352, TrainAcc 1.0, ValAcc 0.7920
# Epoch 035: Loss 0.1307, TrainAcc 1.0, ValAcc 0.7940
# Epoch 036: Loss 0.1318, TrainAcc 1.0, ValAcc 0.7800
# Epoch 037: Loss 0.1297, TrainAcc 1.0, ValAcc 0.7880
# Epoch 038: Loss 0.1276, TrainAcc 1.0, ValAcc 0.7920
# Epoch 039: Loss 0.1283, TrainAcc 1.0, ValAcc 0.7880
# Epoch 040: Loss 0.1265, TrainAcc 1.0, ValAcc 0.7900
# Epoch 041: Loss 0.1249, TrainAcc 1.0, ValAcc 0.7900
# Epoch 042: Loss 0.1244, TrainAcc 1.0, ValAcc 0.7900
# Epoch 043: Loss 0.1230, TrainAcc 1.0, ValAcc 0.7920
# Epoch 044: Loss 0.1215, TrainAcc 1.0, ValAcc 0.7980
# Epoch 045: Loss 0.1207, TrainAcc 1.0, ValAcc 0.7920
# Epoch 046: Loss 0.1201, TrainAcc 1.0, ValAcc 0.7920
# Epoch 047: Loss 0.1187, TrainAcc 1.0, ValAcc 0.8020
# Epoch 048: Loss 0.1181, TrainAcc 1.0, ValAcc 0.7960
# Epoch 049: Loss 0.1182, TrainAcc 1.0, ValAcc 0.7980
# Epoch 050: Loss 0.1170, TrainAcc 1.0, ValAcc 0.7940
# Epoch 051: Loss 0.1168, TrainAcc 1.0, ValAcc 0.7940
# Epoch 052: Loss 0.1170, TrainAcc 1.0, ValAcc 0.7980
# Epoch 053: Loss 0.1161, TrainAcc 1.0, ValAcc 0.7940
# Epoch 054: Loss 0.1158, TrainAcc 1.0, ValAcc 0.7960
# Epoch 055: Loss 0.1157, TrainAcc 1.0, ValAcc 0.8020
# Epoch 056: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7980
# Epoch 057: Loss 0.1151, TrainAcc 1.0, ValAcc 0.8020
# Epoch 058: Loss 0.1146, TrainAcc 1.0, ValAcc 0.8020
# Epoch 059: Loss 0.1144, TrainAcc 1.0, ValAcc 0.7960
# Epoch 060: Loss 0.1145, TrainAcc 1.0, ValAcc 0.8040
# Epoch 061: Loss 0.1141, TrainAcc 1.0, ValAcc 0.8020
# Epoch 062: Loss 0.1138, TrainAcc 1.0, ValAcc 0.7980
# Epoch 063: Loss 0.1139, TrainAcc 1.0, ValAcc 0.8060
# Epoch 064: Loss 0.1139, TrainAcc 1.0, ValAcc 0.8020
# Epoch 065: Loss 0.1137, TrainAcc 1.0, ValAcc 0.7960
# Epoch 066: Loss 0.1136, TrainAcc 1.0, ValAcc 0.7980
# Epoch 067: Loss 0.1136, TrainAcc 1.0, ValAcc 0.8020
# Epoch 068: Loss 0.1135, TrainAcc 1.0, ValAcc 0.8020
# Epoch 069: Loss 0.1136, TrainAcc 1.0, ValAcc 0.7980
# Epoch 070: Loss 0.1137, TrainAcc 1.0, ValAcc 0.8000
# Epoch 071: Loss 0.1137, TrainAcc 1.0, ValAcc 0.8000
# Epoch 072: Loss 0.1137, TrainAcc 1.0, ValAcc 0.8020
# Epoch 073: Loss 0.1138, TrainAcc 1.0, ValAcc 0.8000
# Epoch 074: Loss 0.1138, TrainAcc 1.0, ValAcc 0.8000
# Epoch 075: Loss 0.1137, TrainAcc 1.0, ValAcc 0.8020
# Epoch 076: Loss 0.1138, TrainAcc 1.0, ValAcc 0.8000
# Epoch 077: Loss 0.1139, TrainAcc 1.0, ValAcc 0.8020
# Epoch 078: Loss 0.1139, TrainAcc 1.0, ValAcc 0.7960
# Epoch 079: Loss 0.1140, TrainAcc 1.0, ValAcc 0.8040
# Epoch 080: Loss 0.1142, TrainAcc 1.0, ValAcc 0.7960
# Epoch 081: Loss 0.1144, TrainAcc 1.0, ValAcc 0.8040
# Epoch 082: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7960
# Epoch 083: Loss 0.1148, TrainAcc 1.0, ValAcc 0.8040
# Epoch 084: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 085: Loss 0.1154, TrainAcc 1.0, ValAcc 0.8040
# Epoch 086: Loss 0.1156, TrainAcc 1.0, ValAcc 0.7980
# Epoch 087: Loss 0.1159, TrainAcc 1.0, ValAcc 0.8040
# Epoch 088: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7940
# Epoch 089: Loss 0.1148, TrainAcc 1.0, ValAcc 0.8020
# Epoch 090: Loss 0.1139, TrainAcc 1.0, ValAcc 0.7980
# Epoch 091: Loss 0.1137, TrainAcc 1.0, ValAcc 0.8000
# Epoch 092: Loss 0.1143, TrainAcc 1.0, ValAcc 0.8040
# Epoch 093: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7980
# Epoch 094: Loss 0.1163, TrainAcc 1.0, ValAcc 0.8060
# Epoch 095: Loss 0.1167, TrainAcc 1.0, ValAcc 0.7980
# Epoch 096: Loss 0.1169, TrainAcc 1.0, ValAcc 0.8100
# Epoch 097: Loss 0.1161, TrainAcc 1.0, ValAcc 0.7960
# Epoch 098: Loss 0.1150, TrainAcc 1.0, ValAcc 0.8020
# Epoch 099: Loss 0.1140, TrainAcc 1.0, ValAcc 0.8020
# Epoch 100: Loss 0.1140, TrainAcc 1.0, ValAcc 0.7940
# Epoch 101: Loss 0.1149, TrainAcc 1.0, ValAcc 0.8060
# Epoch 102: Loss 0.1159, TrainAcc 1.0, ValAcc 0.7940
# Epoch 103: Loss 0.1164, TrainAcc 1.0, ValAcc 0.8080
# Epoch 104: Loss 0.1163, TrainAcc 1.0, ValAcc 0.7960
# Epoch 105: Loss 0.1158, TrainAcc 1.0, ValAcc 0.8060
# Epoch 106: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7980
# Epoch 107: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7980
# Epoch 108: Loss 0.1148, TrainAcc 1.0, ValAcc 0.8060
# Epoch 109: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7960
# Epoch 110: Loss 0.1160, TrainAcc 1.0, ValAcc 0.8060
# Epoch 111: Loss 0.1162, TrainAcc 1.0, ValAcc 0.7960
# Epoch 112: Loss 0.1161, TrainAcc 1.0, ValAcc 0.8060
# Epoch 113: Loss 0.1157, TrainAcc 1.0, ValAcc 0.7960
# Epoch 114: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 115: Loss 0.1150, TrainAcc 1.0, ValAcc 0.8040
# Epoch 116: Loss 0.1149, TrainAcc 1.0, ValAcc 0.8000
# Epoch 117: Loss 0.1151, TrainAcc 1.0, ValAcc 0.8040
# Epoch 118: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7960
# Epoch 119: Loss 0.1158, TrainAcc 1.0, ValAcc 0.8060
# Epoch 120: Loss 0.1161, TrainAcc 1.0, ValAcc 0.7960
# Epoch 121: Loss 0.1163, TrainAcc 1.0, ValAcc 0.8080
# Epoch 122: Loss 0.1162, TrainAcc 1.0, ValAcc 0.7940
# Epoch 123: Loss 0.1160, TrainAcc 1.0, ValAcc 0.8040
# Epoch 124: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7980
# Epoch 125: Loss 0.1150, TrainAcc 1.0, ValAcc 0.8020
# Epoch 126: Loss 0.1146, TrainAcc 1.0, ValAcc 0.8000
# Epoch 127: Loss 0.1146, TrainAcc 1.0, ValAcc 0.8020
# Epoch 128: Loss 0.1149, TrainAcc 1.0, ValAcc 0.8040
# Epoch 129: Loss 0.1154, TrainAcc 1.0, ValAcc 0.7980
# Epoch 130: Loss 0.1160, TrainAcc 1.0, ValAcc 0.8080
# Epoch 131: Loss 0.1164, TrainAcc 1.0, ValAcc 0.7980
# Epoch 132: Loss 0.1168, TrainAcc 1.0, ValAcc 0.8020
# Epoch 133: Loss 0.1170, TrainAcc 1.0, ValAcc 0.8000
# Epoch 134: Loss 0.1170, TrainAcc 1.0, ValAcc 0.8060
# Epoch 135: Loss 0.1163, TrainAcc 1.0, ValAcc 0.7940
# Epoch 136: Loss 0.1151, TrainAcc 1.0, ValAcc 0.8020
# Epoch 137: Loss 0.1138, TrainAcc 1.0, ValAcc 0.7960
# Epoch 138: Loss 0.1136, TrainAcc 1.0, ValAcc 0.7960
# Epoch 139: Loss 0.1147, TrainAcc 1.0, ValAcc 0.8040
# Epoch 140: Loss 0.1161, TrainAcc 1.0, ValAcc 0.7960
# Epoch 141: Loss 0.1172, TrainAcc 1.0, ValAcc 0.8080
# Epoch 142: Loss 0.1173, TrainAcc 1.0, ValAcc 0.7940
# Epoch 143: Loss 0.1169, TrainAcc 1.0, ValAcc 0.8020
# Epoch 144: Loss 0.1156, TrainAcc 1.0, ValAcc 0.7900
# Epoch 145: Loss 0.1144, TrainAcc 1.0, ValAcc 0.7960
# Epoch 146: Loss 0.1139, TrainAcc 1.0, ValAcc 0.7960
# Epoch 147: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7940
# Epoch 148: Loss 0.1156, TrainAcc 1.0, ValAcc 0.8100
# Epoch 149: Loss 0.1162, TrainAcc 1.0, ValAcc 0.7940
# Epoch 150: Loss 0.1163, TrainAcc 1.0, ValAcc 0.8040
# Epoch 151: Loss 0.1157, TrainAcc 1.0, ValAcc 0.7900
# Epoch 152: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7960
# Epoch 153: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7960
# Epoch 154: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7960
# Epoch 155: Loss 0.1152, TrainAcc 1.0, ValAcc 0.8060
# Epoch 156: Loss 0.1156, TrainAcc 1.0, ValAcc 0.7920
# Epoch 157: Loss 0.1158, TrainAcc 1.0, ValAcc 0.8080
# Epoch 158: Loss 0.1155, TrainAcc 1.0, ValAcc 0.7940
# Epoch 159: Loss 0.1152, TrainAcc 1.0, ValAcc 0.8020
# Epoch 160: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7920
# Epoch 161: Loss 0.1145, TrainAcc 1.0, ValAcc 0.8000
# Epoch 162: Loss 0.1146, TrainAcc 1.0, ValAcc 0.8000
# Epoch 163: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7940
# Epoch 164: Loss 0.1154, TrainAcc 1.0, ValAcc 0.8020
# Epoch 165: Loss 0.1156, TrainAcc 1.0, ValAcc 0.8000
# Epoch 166: Loss 0.1156, TrainAcc 1.0, ValAcc 0.8040
# Epoch 167: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 168: Loss 0.1151, TrainAcc 1.0, ValAcc 0.8020
# Epoch 169: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7960
# Epoch 170: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7980
# Epoch 171: Loss 0.1145, TrainAcc 1.0, ValAcc 0.8000
# Epoch 172: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7960
# Epoch 173: Loss 0.1149, TrainAcc 1.0, ValAcc 0.8000
# Epoch 174: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 175: Loss 0.1152, TrainAcc 1.0, ValAcc 0.8000
# Epoch 176: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7980
# Epoch 177: Loss 0.1154, TrainAcc 1.0, ValAcc 0.8020
# Epoch 178: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7980
# Epoch 179: Loss 0.1154, TrainAcc 1.0, ValAcc 0.8000
# Epoch 180: Loss 0.1153, TrainAcc 1.0, ValAcc 0.7960
# Epoch 181: Loss 0.1153, TrainAcc 1.0, ValAcc 0.8000
# Epoch 182: Loss 0.1151, TrainAcc 1.0, ValAcc 0.7960
# Epoch 183: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 184: Loss 0.1146, TrainAcc 1.0, ValAcc 0.7960
# Epoch 185: Loss 0.1145, TrainAcc 1.0, ValAcc 0.7980
# Epoch 186: Loss 0.1145, TrainAcc 1.0, ValAcc 0.8020
# Epoch 187: Loss 0.1147, TrainAcc 1.0, ValAcc 0.7920
# Epoch 188: Loss 0.1150, TrainAcc 1.0, ValAcc 0.7980
# Epoch 189: Loss 0.1152, TrainAcc 1.0, ValAcc 0.7900
# Epoch 190: Loss 0.1155, TrainAcc 1.0, ValAcc 0.8020
# Epoch 191: Loss 0.1156, TrainAcc 1.0, ValAcc 0.7900
# Epoch 192: Loss 0.1162, TrainAcc 1.0, ValAcc 0.8000
# Epoch 193: Loss 0.1168, TrainAcc 1.0, ValAcc 0.7940
# Epoch 194: Loss 0.1179, TrainAcc 1.0, ValAcc 0.8020
# Epoch 195: Loss 0.1178, TrainAcc 1.0, ValAcc 0.7900
# Epoch 196: Loss 0.1169, TrainAcc 1.0, ValAcc 0.8020
# Epoch 197: Loss 0.1135, TrainAcc 1.0, ValAcc 0.7940
# Epoch 198: Loss 0.1118, TrainAcc 1.0, ValAcc 0.7880
# Epoch 199: Loss 0.1135, TrainAcc 1.0, ValAcc 0.7940
# Test accuarcy:  0.815000057220459

# %%
plot_loss_and_acc(loss, val_acc)

# %%
# 绘制测试数据的TSNE降维图

tsne = TSNE()
out = tsne.fit_transform(test_logits)

fig = plt.figure()
for i in range(7) :
    indices = test_label == i
    x, y = out[indices].T
    plt.scatter(x, y, label=str(i))

plt.legend()
